# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

##Step1: Load Dataset

dataframe = pd.read_csv("malaria.csv")
#print(dataframe.head())

#Step2: Split into training and test data
x = dataframe.drop(["Label"],axis=1)
y = dataframe["Label"]
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

##Step4: Build a model

model = RandomForestClassifier(n_estimators=100,max_depth=5)
model.fit(x_train,y_train)


##Step5: Make predictions and get classification report

predictions = model.predict(x_test)

print(metrics.classification_report(predictions,y_test))
print(model.score(x_test,y_test))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1145: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
#               precision    recall  f1-score   support
#
#  Parasitized       1.00      1.00      1.00      7856
#  unparatized       0.00      0.00      0.00         0
#
#    micro avg       1.00      1.00      1.00      7856
#    macro avg       0.50      0.50      0.50      7856
# weighted avg       1.00      1.00      1.00      7856
#
# 0.9998727087576375

# %%
import cv2,os
import numpy as np
import csv
import glob

label = "Parasitized"
dirList = glob.glob("cell_images/"+label+"/*.png")
#print(dirList)
file = open("Malaria.csv","a")

for img_path in dirList:

	im = cv2.imread(img_path)
	print(img_path)
	im = cv2.GaussianBlur(im,(5,5),2)



	im_gray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)

	ret,thresh = cv2.threshold(im_gray,127,255,0)
	_,contours,h = cv2.findContours(thresh,1,2)
	
	for contour in contours:
		cv2.drawContours(im_gray, contours, -1, (0,255,0), 3)
	

	cv2.imshow("window",im_gray)

	break


	file.write(label)
	file.write(",")

	for i in range(5):
		try:
			area = cv2.contourArea(contours[i])
			file.write(str(area))
		except:
			file.write("0")

		file.write(",")

	
	file.write("\n")


cv2.waitKey(19000)
# Out:
# cell_images/Parasitized\C100P61ThinF_IMG_20150918_144104_cell_162.png
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-f349ad60f76b> in <module>
#      20
#      21         ret,thresh = cv2.threshold(im_gray,127,255,0)
# ---> 22         _,contours,h = cv2.findContours(thresh,1,2)
#      23
#      24         for contour in contours:
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
# Testing Images
import cv2,os
import numpy as np
import csv
import glob

label = "Parasitized"
dirList = glob.glob("test_cells"+"/*.png")
#print(dirList)
file = open("malaria.csv","a")

for img_path in dirList:

	im = cv2.imread(img_path)
	print(img_path)
	im = cv2.GaussianBlur(im,(5,5),2)



	im_gray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)

	ret,thresh = cv2.threshold(im_gray,127,255,0)
	_,contours,h = cv2.findContours(thresh,1,2)
	
	for contour in contours:
		cv2.drawContours(im_gray, contours, -1, (0,255,0), 3)
	

	cv2.imshow("window",im_gray)


	for i in range(5):
		try:
			area = cv2.contourArea(contours[i])
			file.write(str(area))
		except:
			file.write("0")

		file.write(",")

	
	file.write("\n")


cv2.waitKey(19000)
# Out:
# test_cells\C1_thinF_IMG_20150604_104722_cell_15[1595].png
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-ddc93f375c91> in <module>
#      21
#      22         ret,thresh = cv2.threshold(im_gray,127,255,0)
# ---> 23         _,contours,h = cv2.findContours(thresh,1,2)
#      24
#      25         for contour in contours:
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
df=pd.read_csv("test_malaria.csv",names=['a1','a2','a3','a4','a5'])

# %%
del df['a5']

# %%
df
# Out:
#               a1    a2       a3  a4
# 9056.5       0.0   0.0      0.0   0
# 12675.5      0.0   0.0      0.0   0
# 8270.5       0.0   0.0      0.0   0
# 8700.0       0.0   0.0      0.0   0
# 9415.0       0.0   0.0      0.0   0
# 60.5        68.0  72.5  16005.0   0
# 82.5     13849.5   0.0      0.0   0
# 258.5    14255.5   0.0      0.0   0
# 15630.5      0.0   0.0      0.0   0
# 121.5    10952.5   0.0      0.0   0

# %%
df.reset_index(inplace=True)

# %%
df.rename(columns={'index':'a0'},inplace=True)

# %%
df
# Out:
#         a0       a1    a2       a3  a4
# 0   9056.5      0.0   0.0      0.0   0
# 1  12675.5      0.0   0.0      0.0   0
# 2   8270.5      0.0   0.0      0.0   0
# 3   8700.0      0.0   0.0      0.0   0
# 4   9415.0      0.0   0.0      0.0   0
# 5     60.5     68.0  72.5  16005.0   0
# 6     82.5  13849.5   0.0      0.0   0
# 7    258.5  14255.5   0.0      0.0   0
# 8  15630.5      0.0   0.0      0.0   0
# 9    121.5  10952.5   0.0      0.0   0

# %%
for i in range(len(df)):
    print(model.predict([df.iloc[i]]))
# Out:
# ['Uninfected']
# ['Uninfected']
# ['Uninfected']
# ['Uninfected']
# ['Uninfected']
# ['Parasitized']
# ['Parasitized']
# ['Parasitized']
# ['Uninfected']
# ['Parasitized']
